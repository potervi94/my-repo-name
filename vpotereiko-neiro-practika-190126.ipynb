# %% [markdown]
# <a href="https://www.kaggle.com/code/vpotereyko/vpotereiko-neiro-practika-190126?scriptVersionId=292794054" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import torch
from torchvision import datasets, transforms

# %%
data_dir_0 = '/kaggle/input/leukemia-classification/C-NMC_Leukemia/training_data/fold_0'
data_dir_1 = '/kaggle/input/leukemia-classification/C-NMC_Leukemia/training_data/fold_1'
data_dir_2 = '/kaggle/input/leukemia-classification/C-NMC_Leukemia/training_data/fold_2'

# %%
ds0 = datasets.ImageFolder(data_dir_0)
ds1 = datasets.ImageFolder(data_dir_1)
ds2 = datasets.ImageFolder(data_dir_2)

# %%
len(ds0)
len(ds1)
len(ds2)
# Out:
# 3553

# %%
img0, label0 = ds0[100]
img1, label1 = ds1[100]
img2, label2 = ds2[100]

# %%
print(img0,label0)
print(img1,label1)
print(img2,label2)
# Out:
# <PIL.Image.Image image mode=RGB size=450x450 at 0x7E145AF899D0> 0
# <PIL.Image.Image image mode=RGB size=450x450 at 0x7E145AF6D850> 0
# <PIL.Image.Image image mode=RGB size=450x450 at 0x7E145B01D700> 0

# %%
img0
# Out:
# <PIL.Image.Image image mode=RGB size=450x450>

# %%
img1
# Out:
# <PIL.Image.Image image mode=RGB size=450x450>

# %%
img2
# Out:
# <PIL.Image.Image image mode=RGB size=450x450>

# %%
ds_all = torch.utils.data.ConcatDataset([ds0, ds1, ds2])

# %%
len(ds_all)
# Out:
# 10661

# %%
data_train, data_test = torch.utils.data.random_split(ds_all, [0.8, 0.2])

# %%
len(data_train)
# Out:
# 8529

# %%
len(data_test)
# Out:
# 2132

# %%
train_tr = transforms.Compose(

    transforms.resize([224,224]),
    
)
